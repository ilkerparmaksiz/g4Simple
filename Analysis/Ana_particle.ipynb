# %%
import uproot as up
import matplotlib.pyplot as plt

# %%
f1=up.open("../result_t0.root")

# %%
f1.keys()
# Out:
# ['GPS;1', 'steps;1']

# %%
f1["GPS"].keys()
# Out:
# ['evtid', 'pname', 'pdg', 'x', 'y', 'z', 'kenergy']

# %%
evtid=f1["GPS/evtid"].array().to_numpy() # Mev to ev
print(evtid)
# Out:
# [   0    1    2 ... 9997 9998 9999]

# %%
energy=f1["GPS/kenergy"].array().to_numpy()*1e6 # Mev to ev 
print(len(energy))
print(f"Max Energy {round(energy.max(),2)} eV")
# Out:
# 10000
# Max Energy 22.41 eV

# %%
print(energy)
# Out:
# [ 9.20476419 11.26537547  7.21406478 ...  6.39128125  5.73337865
#   8.74210316]

# %%
_=plt.hist(energy,bins=100)
plt.xlabel("Energy (eV)")
# Out:
# Text(0.5, 0, 'Energy (eV)')
